# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/avelareliandro/analise-exploratoria-de-dados-estatisticos/refs/heads/main/dados_Imobiliario.csv"
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
dados = pd.read_csv(url)

# %%
dados = pd.read_csv(url, sep=";")
# O separador é o ponto e vírgula, pois os dados estão separados por esse caractere.
dados.head()
# O método head() é utilizado para exibir as primeiras linhas do DataFrame, permitindo uma visualização rápida dos dados.
dados.info()
# O método info() fornece informações sobre o DataFrame, como o número de entradas, colunas, tipos de dados e valores nulos.
dados.describe()
# O método describe() gera estatísticas descritivas para as colunas numéricas do DataFrame, como média, desvio padrão, valores mínimos e máximos, entre outros.
dados.describe(include="all")
# O método describe() com o parâmetro include="all" inclui estatísticas descritivas para todas as colunas, incluindo as categóricas.
dados["Valor"].mean()
# O método mean() calcula a média da coluna "Valor", que representa o preço dos imóveis.
dados["Valor"].median()
# O método median() calcula a mediana da coluna "Valor", que é o valor central quando os dados estão ordenados.
dados["Valor"].mode()   
# O método mode() retorna o valor mais frequente na coluna "Valor". Se houver mais de um valor com a mesma frequência, ele retornará todos eles.
dados["Valor"].min()
# O método min() retorna o valor mínimo da coluna "Valor", ou seja, o preço mais baixo dos imóveis.
dados["Valor"].max()
# O método max() retorna o valor máximo da coluna "Valor", ou seja, o preço mais alto dos imóveis.
dados["Valor"].std()
# O método std() calcula o desvio padrão da coluna "Valor", que é uma medida de dispersão dos dados em relação à média.
dados["Valor"].var()
# O método var() calcula a variância da coluna "Valor", que é outra medida de dispersão dos dados em relação à média.
dados["Valor"].quantile(0.25)       
# O método quantile(0.25) retorna o primeiro quartil (Q1) da coluna "Valor", que é o valor abaixo do qual 25% dos dados estão localizados.
dados["Valor"].quantile(0.5)
# O método quantile(0.5) retorna o segundo quartil (Q2) ou mediana da coluna "Valor", que é o valor abaixo do qual 50% dos dados estão localizados.
dados["Valor"].quantile(0.75)
# O método quantile(0.75) retorna o terceiro quartil (Q3) da coluna "Valor", que é o valor abaixo do qual 75% dos dados estão localizados.
dados["Valor"].quantile(0.95)
# O método quantile(0.95) retorna o percentil 95 da coluna "Valor", que é o valor abaixo do qual 95% dos dados estão localizados.
type(dados)
# O comando type() é utilizado para verificar o tipo do objeto "dados", que é um DataFrame do pandas.
dados.shape
# O atributo shape retorna uma tupla com o número de linhas e colunas do DataFrame
dados[["Valor", "Quartos"]]
# O comando dados[["Valor", "Quartos"]] seleciona as colunas "Valor" e "Quartos" do DataFrame, retornando um novo DataFrame contendo apenas essas duas colunas.

#
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  str
#  1   Bairro      32960 non-null  str
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), str(2)
# memory usage: 2.3 MB
#         Valor  Quartos
# 0      1700.0        1
# 1      7000.0        2
# 2      5200.0        0
# 3       800.0        1
# 4       800.0        1
# ...       ...      ...
# 32955   800.0        0
# 32956  1800.0        3
# 32957  1400.0        2
# 32958  3000.0        2
# 32959  6500.0        0
#
# [32960 rows x 2 columns]

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor'].mean()
# Out:
# np.float64(12952.659715265761)

# %%
dados.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo').mean(numeric_only=True)
# O método groupby() é utilizado para agrupar os dados com base na coluna "Tipo". Em seguida, o método mean() é aplicado para calcular a média dos valores agrupados, e o parâmetro numeric_only=True garante que apenas as colunas numéricas sejam consideradas no cálculo da média.
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
dados.groupby('Tipo')['Valor'].mean()
# O método groupby() é utilizado para agrupar os dados com base na coluna "Tipo". Em seguida, o método mean() é aplicado para calcular a média dos valores agrupados, e o parâmetro numeric_only=True garante que apenas as colunas numéricas sejam consideradas no cálculo da média.
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')    
# O método groupby() é utilizado para agrupar os dados com base na coluna "Tipo". Em seguida, o método mean() é aplicado para calcular a média dos valores agrupados, e o método sort_values('Valor') é utilizado para ordenar os resultados com base na coluna "Valor" em ordem crescente.
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# O comando dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor') agrupa os dados por "Tipo", calcula a média da coluna "Valor" para cada grupo e ordena os resultados com base na coluna "Valor" em ordem crescente. O resultado é armazenado na variável df_peco_tip.
df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');
# O comando df_preco_tipo.plot(kind='barh', figsize=(14, 10), color='purple') cria um gráfico de barras horizontais (barh) utilizando os dados do DataFrame df_preco_tipo. O parâmetro figsize=(14, 10) define o tamanho do gráfico, e color='purple' especifica a cor das barras como roxa.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
f_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# O comando dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor') agrupa os dados por "Tipo", calcula a média da coluna "Valor" para cada grupo e ordena os resultados com base na coluna "Valor" em ordem crescente. O resultado é armazenado na variável df_peco_tip.
df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');
# O comando df_preco_tipo.plot(kind='barh', figsize=(14, 10), color='purple') cria um gráfico de barras horizontais (barh) utilizando os dados do DataFrame df_preco_tipo. O parâmetro figsize=(14, 10) define o tamanho do gráfico, e color='purple' especifica a cor das barras como roxa.
